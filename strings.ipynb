# %%
#single word
my_string= "world"
print(my_string)
# Out:
# world

# %%
#entire phrase
paragraph= "Today's weather is very beautiful not so cold and not so hot."
print(paragraph)

# %%
#statment to the type of the variable
list=("list of the groceries for the event")
type(list)

# %%
#assign a string
system=("string contains alphabatical values in it.")
print(system)
# Out:
# string contains alphabatical values in it.

# %%
#length of the string
len(system)
# Out:
# 42

# %%
#show the element
system=("string contains alphabatical values in it.")
print(system[2])
print(system[24])
print(system[-15])
# Out:
# r
# i
# l

# %%
#slicing of the string
Chemistry= ("chemistry is all about the chemical reaction where two or more than two compound reacts with each other give new compound.")
len(Chemistry)
# Out:
# 122

# %%
#slicing
print(string[1:7])
print(string[10:44])
print(string[10:44:2])
print(string[24:29:35])
print(string[-4:-13])
print(string[-6:-8])
# Out:
# tring
# tains alphabatical values in it.
# tisapaaia ausi t
# i

# %%
#addition of string
string1=("HELLO")
string2= ("WORLD")
print(string1 + string2)
print(string1+ " " + string2)
# Out:
# HELLOWORLD
# HELLO WORLD

# %%
AA= len(string1)
BB= len(string2)

# %%
#string functions
spring1=("Programming in python")
spring2=("data Science")
print(spring1.lower())
print(spring2.lower())
print(spring1.upper())
print(spring2.upper())
print(spring1.swapcase())
print(spring2.swapcase())
# Out:
# programming in python
# data science
# PROGRAMMING IN PYTHON
# DATA SCIENCE
# pROGRAMMING IN PYTHON
# DATA sCIENCE

# %%
#string lower, upper, swapcases
str1=("Inorganic")
str2=("Chemistry")
print(str1.lower())
print(str2.upper())
print(str1.swapcase())
print(str2.swapcase())
# Out:
# inorganic
# CHEMISTRY
# iNORGANIC
# cHEMISTRY

# %%
#find
str1.find("s")
spring1.find("ming")
string1.find("O")
# Out:
# 4

# %%
#replace
string2.replace("Chemistry", "Inorganic")
str2.replace("Chenistry", "Organic")
# Out:
# 'Chemistry'
