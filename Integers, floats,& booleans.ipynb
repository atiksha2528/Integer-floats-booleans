# %%
#addition
3+5
# Out:
# 8

# %%
#substraction
9-2
# Out:
# 7

# %%
#multiplication
6*4
# Out:
# 24

# %%
#division
8/3
# Out:
# 2.6666666666666665

# %%
#floor division
9//4
# Out:
# 2

# %%
#exponentiation
7**3
# Out:
# 343

# %%
#modulus
12%3
# Out:
# 0

# %%
#order of opertaion
4+6 * 5-3
# Out:
# 31
# 31

# %%
#scientific notation
6E4
# Out:
# 60000.0

# %%
#variable
a=24
a
# Out:
# 24

# %%
#addition
s=2
t=8
p= s+t
print(p)
# Out:
# 10

# %%
a=6
b=9
#substraction
k=a-b
print(k)

#multiplication
k=a*b
print(k)

#division
k=b/a
print(k)
type(k)

#floor division
k=a//b
print(k)
# Out:
# -3
# 54
# 1.5
# 0

# %%
#set the object to be a boolean
boolean_variable= True
type(boolean_variable)
# Out:
# bool

# %%
#show
boolean_variable
# Out:
# True

# %%
#equal
5==8
# Out:
# False

# %%
#not equal
4!=8
# Out:
# True

# %%
#greater than
a=7
b=4
a>b
# Out:
# True

# %%
#less than
s=9
c=4
c<s
# Out:
# True

# %%
#greaterthan or equal to
f=7
d=2
d>=f
# Out:
# False

# %%
#less than or equal to
u=3
v=5
v<=u
# Out:
# False
