# %% [markdown]
# <a href="https://colab.research.google.com/github/atiksha2528/Integer-floats-booleans/blob/main/List_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#assign a list to an variable named my_list


my_list=['A string',23,100,232,'o',True]

print(my_list)

type(my_list)

my_list

len(my_list)

#consider a list of strings
loss_function = ['mean absolute error', 'mean squarred erroe', 'hubberloss','huber loss','log loss','hinge loss']
print(loss_function)


#grab the element at index 0, which is first element
print(loss_function[0])




len(loss_function)


#grab the element at index 3, which is the FOURTH element
print(loss_function[3])


print(loss_function[5])


#grab the element at the index -1, which is the LAST element
print(loss_function[-1])


#grab the element at the index -3, which is the THIRD LAST element
print(loss_function[-3])

#print our list
print(loss_function)

#grab the elements starting from index 1 and everything past it
loss_function[1:4]

#grab everything starting from index 2
loss_function[2:]

#grab everything before the index 4
loss_function[:4]

#grab everything
print(loss_function[:1])

#grab the LAST FOUR elements of the list
loss_function[-4:]

loss_function[-2]

len(loss_function)

loss_function[4]

print(loss_function)

loss_function + ['kullback-leibler']

print(loss_function)

#reassign
loss_function = loss_function + ['kullback-leibler']

loss_function

#make the list double
len(loss_function*5)

#create a new list
my_list=[1,2,3,1,1,1,3,10,5,8]

#print the list
my_list

len(my_list)

print(my_list)

len(my_list)

#show
my_list.append(2.73)

print(my_list)
len(my_list)

my_list.append([10,[19,20],30])

my_list

#print the list
print(my_list)

#pop off the 0 indexed item
my_list.pop()

print(my_list)

#assign the popped element, remember default popped index is -1
my_list.pop(1)

len(my_list)

print(my_list)

new_list = [6,9,1,3,5]

#use sort the list (this is permanent!)
new_list.sort()

print(new_list)

#use the reverse boolean to set the ascending or descending order
new_list.sort(reverse=True)
print(new_list)

boolean_list=[True,False]

boolean_list.sort(reverse=True)

print(boolean_list)

#let's make three lists
1 == [1,2,3]
2 == ['b','a','d']
3 == [7,8,9]

#make a list of list to form a  matrix
list_of_list=[1,2,3]

print(list_of_list)

#show
type(list_of_list)

#grab first item in matrix object
list_of_list[1]

#grab first item of the first item in the matrix object
list_of_list[1]
# Out:
# ['A string', 23, 100, 232, 'o', True]
# ['mean absolute error', 'mean squarred erroe', 'hubberloss', 'huber loss', 'log loss', 'hinge loss']
# mean absolute error
# huber loss
# hinge loss
# hinge loss
# huber loss
# ['mean absolute error', 'mean squarred erroe', 'hubberloss', 'huber loss', 'log loss', 'hinge loss']
# ['mean absolute error']
# ['mean absolute error', 'mean squarred erroe', 'hubberloss', 'huber loss', 'log loss', 'hinge loss']
# ['mean absolute error', 'mean squarred erroe', 'hubberloss', 'huber loss', 'log loss', 'hinge loss']
# [1, 2, 3, 1, 1, 1, 3, 10, 5, 8]
# [1, 2, 3, 1, 1, 1, 3, 10, 5, 8, 2.73]
# [1, 2, 3, 1, 1, 1, 3, 10, 5, 8, 2.73, [10, [19, 20], 30]]
# [1, 2, 3, 1, 1, 1, 3, 10, 5, 8, 2.73]
# [1, 3, 1, 1, 1, 3, 10, 5, 8, 2.73]
# [1, 3, 5, 6, 9]
# [9, 6, 5, 3, 1]
# [True, False]
# [1, 2, 3]
# 2
